# %%
import numpy as np
import pandas as pd
from six.moves import zip
from os import listdir

from bokeh.plotting import figure, show, output_notebook

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b601c822-1ea5-4f1d-9c9c-9d70b79e05c8">Loading BokehJS ...</span>
#     </div>

# %%
N = 4000

x = np.random.random(size=N) * 100
y = np.random.random(size=N) * 100
radii = np.random.random(size=N) * 1.5

# %%
TOOLS="hover,crosshair,pan,wheel_zoom,box_zoom,reset,tap,save,box_select,poly_select,lasso_select"

colors2 = ["#%02x%02x%02x" % (int(r), int(g), 150) for r, g in zip(50+2*x, 30+2*y)]
p1 = figure(width=300, height=300, tools=TOOLS)
p1.scatter(x,y, radius=radii, fill_color=colors2, fill_alpha=0.6, line_color=None)

colors2 = ["#%02x%02x%02x" % (150, int(g), int(b)) for g, b in zip(50+2*x, 30+2*y)]
p2 = figure(width=300, height=300, tools=TOOLS)
p2.scatter(x,y, radius=radii, fill_color=colors2, fill_alpha=0.6, line_color=None)

# %%
show(p1)
show(p2)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="04eb258a-657e-4153-bd47-8de7f0eaeae2"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#04eb258a-657e-4153-bd47-8de7f0eaeae2").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("04eb258a-657e-4153-bd47-8de7f0eaeae2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '04eb258a-657e-4153-bd47-8de7f0eaeae2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"2d0b2204-34b7-4eef-bb70-9fb59b4906f9":{"roots":{"references":[{"attributes":{"callback":null},"id":"07c67786-e868-4d39-a6dc-29bd07d70a70","type":"DataRange1d"},{"attributes":{"callback":null,"overlay":{"id":"3f04c569-f4cb-480e-ab65-56c8f66b87da","type":"PolyAnnotation"},"plot":{"id":"63d8a20c-1ab2-4481-81d8-21bbec86adb7","subtype":"Figure","type":"Plot"}},"id":"7613873d-3969-467b-8b8d-d80bf21d73ce","type":"LassoSelectTool"},{"attributes":{"callback":null,"plot":{"id":"63d8a20c-1ab2-4481-81d8-21bbec86adb7","subtype":"Figure","type":"Plot"}},"id":"66f03e0c-f5e0-4301-b9ec-e5cacd9124d1","type":"HoverTool"},{"attributes":{"overlay":{"id":"5bae6d8a-8397-48bf-abae-5f87f4a0787a","type":"BoxAnnotation"},"plot":{"id":"63d8a20c-1ab2-4481-81d8-21bbec86adb7","subtype":"Figure","type":"Plot"}},"id":"ad6e24fc-68a3-4de6-b9de-ca537d106057","type":"BoxZoomTool"},{"attributes":{},"id":"73e8fea9-0b82-43a8-a15f-6fa33be85fb7","type":"BasicTicker"},{"attributes":{"callback":null},"id":"02bf51d1-f014-4fbf-ab75-3e6ddc48f9f6","type":"DataRange1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"38b3d90f-7152-4e98-ad79-31620287e00a","type":"BoxAnnotation"},{"attributes":{"callback":null,"overlay":{"id":"38b3d90f-7152-4e98-ad79-31620287e00a","type":"BoxAnnotation"},"plot":{"id":"63d8a20c-1ab2-4481-81d8-21bbec86adb7","subtype":"Figure","type":"Plot"},"renderers":[{"id":"ecc3d0c2-295b-4699-b822-93fcf1607077","type":"GlyphRenderer"}]},"id":"36d3eece-b5ce-4f9e-909a-f3d6545140a6","type":"BoxSelectTool"},{"attributes":{"plot":null,"text":null},"id":"1e805f60-8a38-4708-887a-6569fdb55374","type":"Title"},{"attributes":{},"id":"5c262ae0-3ede-45bd-9606-9115d247f109","type":"BasicTickFormatter"},{"attributes":{},"id":"0a7a7e44-d98b-416d-a27b-68ab31456f1a","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x","y","radius","fill_color"],"data":{"fill_color":["#a35996","#4d9896","#8da196","#43b596","#765e96","#c0c596","#b57396","#e85696","#8d5c96","#c5b796","#6db296","#6e5b96","#e54996","#c93996","#642296","#5a7c96","#ec7796","#a32e96","#a2ab96","#68da96","#54c996","#747596","#ef9396","#aeb496","#686d96","#4e6196","#b76b96","#d29f96","#70a296","#8b2d96","#708e96","#a56d96","#cb5196","#e7a096","#663696","#e24696","#6fce96","#8bc996","#9b2196","#d8d696","#b39d96","#4f3e96","#977296","#76d796","#b84896","#7dc596","#f4c196","#c28596","#e7c196","#8da696","#eee196","#8d5a96","#623996","#de5796","#a59896","#62c496","#abb996","#917596","#8f4196","#a9ce96","#df9f96","#8e3f96","#387896","#6a5796","#9e8296","#f0e396","#3a1f96","#b49396","#5acf96","#f5ac96","#d57c96","#e72396","#3a7596","#d2a496","#b1cb96","#923596","#ba5196","#3edb96","#e49196","#c98a96","#8c8296","#53c996","#39bf96","#34b896","#bad296","#805196","#dd2396","#496396","#926696","#7fba96","#4ab696","#e2b996","#386996","#414b96","#367196","#e45696","#b94696","#5a9b96","#ef4196","#f4b496","#8c9496","#f46796","#41dc96","#617096","#57e196","#f07796","#5cb296","#513696","#f05596","#aebf96","#4ee096","#a9a896","#f67d96","#698f96","#676f96","#b14196","#3e5e96","#c54996","#39a996","#e23696","#f97396","#677696","#bd8e96","#f98896","#7e2096","#39d396","#897396","#e18396","#658696","#635396","#db9a96","#cd6c96","#994f96","#485f96","#356396","#a0ba96","#56af96","#63d696","#f4a596","#745196","#7ec296","#a22396","#abc096","#e12c96","#f82296","#3e6396","#e98d96","#f3db96","#cb4596","#8a4096","#e73a96","#478a96","#b54196","#742196","#ddab96","#bc7c96","#b18e96","#c9c096","#c81e96","#9b8396","#b26296","#e98a96","#4ee496","#4fc496","#368896","#854896","#6e5c96","#e61f96","#df6096","#3ca796","#7c9f96","#e7c196","#bd7196","#da9996","#6d5b96","#c82f96","#4ca296","#8b2d96","#9bb096","#64bf96","#58b696","#918b96","#70 ...
#     <div class="bk-root">
#         <div class="plotdiv" id="684059a8-08cc-4475-bb59-eb6a639f80b0"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#684059a8-08cc-4475-bb59-eb6a639f80b0").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("684059a8-08cc-4475-bb59-eb6a639f80b0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '684059a8-08cc-4475-bb59-eb6a639f80b0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"8c098b96-b8e6-490e-a98d-87eba4bf83f2":{"roots":{"references":[{"attributes":{"callback":null,"overlay":{"id":"35ccc1cf-9516-4a37-8e37-8ac570463f77","type":"PolyAnnotation"},"plot":{"id":"6f371542-ca99-47b2-9e56-cf0e7cbf20fd","subtype":"Figure","type":"Plot"}},"id":"124b6b2e-e234-4c4e-8fb5-ce62ccb9e914","type":"LassoSelectTool"},{"attributes":{"overlay":{"id":"a76b5187-ff68-4923-af7b-f95c3359bbfc","type":"BoxAnnotation"},"plot":{"id":"6f371542-ca99-47b2-9e56-cf0e7cbf20fd","subtype":"Figure","type":"Plot"}},"id":"4104e1c1-af8c-46a7-90b4-d318d77849d5","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"6f371542-ca99-47b2-9e56-cf0e7cbf20fd","subtype":"Figure","type":"Plot"}},"id":"d5feffe2-f149-4e9b-8f6c-6c6dfb42341c","type":"ResetTool"},{"attributes":{"plot":{"id":"6f371542-ca99-47b2-9e56-cf0e7cbf20fd","subtype":"Figure","type":"Plot"}},"id":"a3294e0a-d4be-479a-8da0-8bc3112f1f22","type":"PanTool"},{"attributes":{"plot":null,"text":null},"id":"8218bc3a-ec3f-4697-8122-7cc87ddea431","type":"Title"},{"attributes":{"overlay":{"id":"92c43285-ce2e-4acf-8465-ced18fc89659","type":"PolyAnnotation"},"plot":{"id":"6f371542-ca99-47b2-9e56-cf0e7cbf20fd","subtype":"Figure","type":"Plot"}},"id":"14bfd13e-ee4d-40fc-915f-12bd63bd6930","type":"PolySelectTool"},{"attributes":{"fill_alpha":{"value":0.6},"fill_color":{"field":"fill_color"},"line_color":{"value":null},"radius":{"field":"radius","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ca082a35-f070-4df5-a2a2-ecbf1460d09e","type":"Circle"},{"attributes":{"data_source":{"id":"22c72d76-8adf-49da-9bb8-23af62799a50","type":"ColumnDataSource"},"glyph":{"id":"ca082a35-f070-4df5-a2a2-ecbf1460d09e","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"357931c1-6eac-4702-b791-e1e0d18e29e5","type":"Circle"},"selection_glyph":null},"id":"b621fef8-5741-4364-8c89-69b145f34ecb","type":"GlyphRenderer"},{"attributes":{},"id":"bfa687eb-1453-41e8-ad39-4b6f083eda8e","type":"BasicTicker"},{"attributes":{"plot":{"id":"6f371542-ca99-47b2-9e56-cf0e7cbf20fd","subtype":"Figure","type":"Plot"}},"id":"52c1d9ec-3f2a-4e97-a3e8-e001f427d2dc","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"6f371542-ca99-47b2-9e56-cf0e7cbf20fd","subtype":"Figure","type":"Plot"}},"id":"1aa8fe46-5c00-47c6-9858-53817cf3a7bf","type":"CrosshairTool"},{"attributes":{"callback":null},"id":"c67ec806-0e6e-4ebc-9bae-00a429a35d2d","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["x","y","radius","fill_color"],"data":{"fill_color":["#96a359","#964d98","#968da1","#9643b5","#96765e","#96c0c5","#96b573","#96e856","#968d5c","#96c5b7","#966db2","#966e5b","#96e549","#96c939","#966422","#965a7c","#96ec77","#96a32e","#96a2ab","#9668da","#9654c9","#967475","#96ef93","#96aeb4","#96686d","#964e61","#96b76b","#96d29f","#9670a2","#968b2d","#96708e","#96a56d","#96cb51","#96e7a0","#966636","#96e246","#966fce","#968bc9","#969b21","#96d8d6","#96b39d","#964f3e","#969772","#9676d7","#96b848","#967dc5","#96f4c1","#96c285","#96e7c1","#968da6","#96eee1","#968d5a","#966239","#96de57","#96a598","#9662c4","#96abb9","#969175","#968f41","#96a9ce","#96df9f","#968e3f","#963878","#966a57","#969e82","#96f0e3","#963a1f","#96b493","#965acf","#96f5ac","#96d57c","#96e723","#963a75","#96d2a4","#96b1cb","#969235","#96ba51","#963edb","#96e491","#96c98a","#968c82","#9653c9","#9639bf","#9634b8","#96bad2","#968051","#96dd23","#964963","#969266","#967fba","#964ab6","#96e2b9","#963869","#96414b","#963671","#96e456","#96b946","#965a9b","#96ef41","#96f4b4","#968c94","#96f467","#9641dc","#966170","#9657e1","#96f077","#965cb2","#965136","#96f055","#96aebf","#964ee0","#96a9a8","#96f67d","#96698f","#96676f","#96b141","#963e5e","#96c549","#9639a9","#96e236","#96f973","#966776","#96bd8e","#96f988","#967e20","#9639d3","#968973","#96e183","#966586","#966353","#96db9a","#96cd6c","#96994f","#96485f","#963563","#96a0ba","#9656af","#9663d6","#96f4a5","#967451","#967ec2","#96a223","#96abc0","#96e12c","#96f822","#963e63","#96e98d","#96f3db" ...

# %% [markdown]
# Find all the log files in the log directory

# %%
files = listdir('logs')
log_files = []
for file in files:
    if file.endswith('.log'):
        log_files.append(file)
    else:
        print('FYI - Non log file detected and ignored in data folder - ', file)
print('Succesfully identified', len(log_files), 'log file(s)')
# Out:
# Succesfully identified  1  log files

# %% [markdown]
# Import the log files into a list of lists

# %%
raw_log_import_list = []
ignored_lines = []
for log_file_name in log_files:
    raw_file = open('logs\\' + str(log_file_name))
    raw_log_import_list.append(raw_file)
for raw_file in raw_log_import_list:
    file_watch = str(raw_file)
    # ingest - readlines, then reformat (lower, strip space, split by ',')
    file_data_table = []
    file_line = raw_file.readline()
    while file_line:
        try:
            date = file_line[0:10]
            time = file_line[11:23]
            event = file_line[69:73].split('-')[0]
            log_event_detail = file_line[73:].split('{')[1][:-4].split(', \'')
            file_data_table.append((raw_file,date,time,event,log_event_detail))
        except:
            ignored_lines.append((raw_file,file_line))
        file_line = raw_file.readline()

# %%
file_data_table
# Out:
# [(<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:54:59,449',
#   '17',
#   ['']),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:04,440',
#   '1',
#   ["'gain': 0", "'state': 1"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:04,440',
#   '4',
#   ["'rel': (995",
#    '878)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (994",
#    '877)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:04,441',
#   '1',
#   ["'gain': 1", "'state': 1"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:04,441',
#   '4',
#   ["'rel': (-1",
#    '0)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (993",
#    '877)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:04,450',
#   '4',
#   ["'rel': (-36",
#    '21)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (957",
#    '898)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:04,642',
#   '3',
#   ["'scancode': 46", "'key': 99", "'window': None", "'mod': 0"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:04,643',
#   '4',
#   ["'rel': (-23",
#    '-153)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (984",
#    '617)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:04,770',
#   '4',
#   ["'rel': (-63",
#    '-32)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (921",
#    '585)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:04,915',
#   '4',
#   ["'rel': (-915",
#    '-585)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (6",
#    '0)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:04,924',
#   '1',
#   ["'gain': 0", "'state': 1"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:05,108',
#   '1',
#   ["'gain': 1", "'state': 1"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:05,109',
#   '4',
#   ["'rel': (72",
#    '103)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (78",
#    '103)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:05,125',
#   '4',
#   ["'rel': (54",
#    '53)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (132",
#    '156)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:05,142',
#   '4',
#   ["'rel': (14",
#    '23)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (146",
#    '179)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:05,158',
#   '4',
#   ["'rel': (2",
#    '4)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (148",
#    '183)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:05,261',
#   '4',
#   ["'rel': (-7",
#    '0)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (141",
#    '183)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:05,279',
#   '4',
#   ["'rel': (-64",
#    '-18)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (77",
#    '165)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:05,295',
#   '4',
#   ["'rel': (-34",
#    '-12)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (43",
#    '153)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:05,315',
#   '4',
#   ["'rel': (-4",
#    '-2)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (39",
#    '151)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:05,332',
#   '4',
#   ["'rel': (-1",
#    '0)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (38",
#    '151)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:05,348',
#   '4',
#   ["'rel': (2",
#    '-3)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (40",
#    '148)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:05,364',
#   '4',
#   ["'rel': (27",
#    '-21)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (67",
#    '127)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:05,383',
#   '4',
#   ["'rel': (42",
#    '-28)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (109",
#    '99)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:05,398',
#   '4',
#   ["'rel': (24",
#    '-19)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (133",
#    '80)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:05,414',
#   '4',
#   ["'rel': (13",
#    '-12)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (146",
#    '68)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:05,433',
#   '4',
#   ["'rel': (9",
#    '-12)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (155",
#    '56)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:05,449',
#   '4',
#   ["'rel': (2",
#    '-3)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (157",
#    '53)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:05,685',
#   '4',
#   ["'rel': (-6",
#    '17)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (151",
#    '70)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:05,703',
#   '4',
#   ["'rel': (-10",
#    '22)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (141",
#    '92)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:05,719',
#   '4',
#   ["'rel': (-5",
#    '10)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (136",
#    '102)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:05,736',
#   '4',
#   ["'rel': (0",
#    '1)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (136",
#    '103)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:05,894',
#   '5',
#   ["'button': 1", "'pos': (137", '103)', "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:05,895',
#   '9.1',
#   ["'pos': (139,104),'distance: 75.21303078589507,'relative_loc: (44",
#    "61),'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:05,896',
#   '4',
#   ["'rel': (2",
#    '1)',
#    "'buttons': (1",
#    '0',
#    '0)',
#    "'pos': (139",
#    '104)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:06,016',
#   '6',
#   ["'button': 1", "'pos': (139", '104)', "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:06,090',
#   '4',
#   ["'rel': (8",
#    '5)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (147",
#    '109)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:06,107',
#   '4',
#   ["'rel': (21",
#    '17)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (168",
#    '126)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:06,123',
#   '4',
#   ["'rel': (20",
#    '21)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (188",
#    '147)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:06,142',
#   '4',
#   ["'rel': (19",
#    '24)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (207",
#    '171)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:06,158',
#   '4',
#   ["'rel': (11",
#    '19)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (218",
#    '190)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:06,175',
#   '4',
#   ["'rel': (6",
#    '9)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (224",
#    '199)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:06,191',
#   '4',
#   ["'rel': (1",
#    '1)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (225",
#    '200)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:06,305',
#   '4',
#   ["'rel': (1",
#    '17)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (226",
#    '217)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:06,420',
#   '4',
#   ["'rel': (-3",
#    '13)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (223",
#    '230)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:06,615',
#   '4',
#   ["'rel': (0",
#    '1)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (223",
#    '231)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:06,684',
#   '4',
#   ["'rel': (11",
#    '1)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (234",
#    '232)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:06,700',
#   '4',
#   ["'rel': (19",
#    '1)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (253",
#    '233)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:06,716',
#   '4',
#   ["'rel': (24",
#    '1)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (277",
#    '234)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:06,734',
#   '4',
#   ["'rel': (25",
#    '0)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (302",
#    '234)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:06,750',
#   '4',
#   ["'rel': (22",
#    '1)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (324",
#    '235)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:06,768',
#   '4',
#   ["'rel': (31",
#    '0)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (355",
#    '235)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:06,785',
#   '4',
#   ["'rel': (25",
#    '-1)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (380",
#    '234)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:06,801',
#   '4',
#   ["'rel': (24",
#    '-1)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (404",
#    '233)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:06,817',
#   '4',
#   ["'rel': (21",
#    '-1)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (425",
#    '232)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:06,933',
#   '4',
#   ["'rel': (47",
#    '-13)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (472",
#    '219)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:07,056',
#   '4',
#   ["'rel': (13",
#    '-34)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (485",
#    '185)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:07,234',
#   '4',
#   ["'rel': (152",
#    '136)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (637",
#    '321)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:07,357',
#   '4',
#   ["'rel': (1",
#    '-3)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (638",
#    '318)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:07,375',
#   '4',
#   ["'rel': (3",
#    '-3)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (641",
#    '315)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:07,392',
#   '4',
#   ["'rel': (8",
#    '-5)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (649",
#    '310)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:07,409',
#   '4',
#   ["'rel': (17",
#    '-9)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (666",
#    '301)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:07,426',
#   '4',
#   ["'rel': (14",
#    '-9)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (680",
#    '292)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:07,443',
#   '4',
#   ["'rel': (9",
#    '-6)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (689",
#    '286)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:07,461',
#   '4',
#   ["'rel': (6",
#    '-4)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (695",
#    '282)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:07,478',
#   '4',
#   ["'rel': (2",
#    '-2)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (697",
#    '280)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:07,597',
#   '5',
#   ["'button': 1", "'pos': (697", '280)', "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:07,597',
#   '8',
#   ["'reason': <bound method GameManager.pause of <game.GameManager object at 0x000001C8561F5320>> "]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:09,526',
#   '7',
#   ["'': hit_conf49 "]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:09,857',
#   '7',
#   ["'': reward_conf50 "]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:10,056',
#   '7',
#   ["'': player_skill50 "]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:10,056',
#   '9.1',
#   ["'pos': (697,280),'distance: 61.84658438426491,'relative_loc: (39",
#    "48),'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:10,205',
#   '2',
#   ["'scancode': 4",
#    "'key': 51",
#    "'window': None",
#    "'mod': 0",
#    "'unicode': '3'"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:10,239',
#   '3',
#   ["'scancode': 3", "'key': 50", "'window': None", "'mod': 0"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:10,324',
#   '3',
#   ["'scancode': 4", "'key': 51", "'window': None", "'mod': 0"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:10,807',
#   '4',
#   ["'rel': (36",
#    '-62)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (667",
#    '328)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:10,824',
#   '4',
#   ["'rel': (-34",
#    '0)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (633",
#    '328)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:10,841',
#   '4',
#   ["'rel': (-29",
#    '2)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (604",
#    '330)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:10,858',
#   '4',
#   ["'rel': (-20",
#    '0)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (584",
#    '330)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:10,876',
#   '4',
#   ["'rel': (-6",
#    '1)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (578",
#    '331)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:10,892',
#   '4',
#   ["'rel': (-1",
#    '0)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (577",
#    '331)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:10,909',
#   '4',
#   ["'rel': (-1",
#    '0)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (576",
#    '331)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:10,943',
#   '4',
#   ["'rel': (-2",
#    '0)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (574",
#    '331)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:10,960',
#   '4',
#   ["'rel': (-10",
#    '-1)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (564",
#    '330)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:10,976',
#   '4',
#   ["'rel': (-20",
#    '-3)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (544",
#    '327)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:11,086',
#   '4',
#   ["'rel': (-65",
#    '-11)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (479",
#    '316)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:11,202',
#   '4',
#   ["'rel': (-12",
#    '-7)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (467",
#    '309)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:11,341',
#   '4',
#   ["'rel': (-12",
#    '10)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (455",
#    '319)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:11,363',
#   '4',
#   ["'rel': (87",
#    '-38)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (542",
#    '281)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:11,374',
#   '4',
#   ["'rel': (57",
#    '-35)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (599",
#    '246)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:11,391',
#   '4',
#   ["'rel': (85",
#    '-72)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (684",
#    '174)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:11,409',
#   '4',
#   ["'rel': (50",
#    '-70)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (734",
#    '104)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:11,425',
#   '4',
#   ["'rel': (23",
#    '-47)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (757",
#    '57)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:11,443',
#   '4',
#   ["'rel': (5",
#    '-32)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (762",
#    '25)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:11,461',
#   '4',
#   ["'rel': (0",
#    '-18)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (762",
#    '7)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:11,476',
#   '4',
#   ["'rel': (0",
#    '-7)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (762",
#    '0)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:11,494',
#   '1',
#   ["'gain': 0", "'state': 1"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:11,614',
#   '1',
#   ["'gain': 1", "'state': 1"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:11,614',
#   '4',
#   ["'rel': (-81",
#    '10)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (681",
#    '10)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:11,633',
#   '4',
#   ["'rel': (-38",
#    '18)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (643",
#    '28)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:11,647',
#   '4',
#   ["'rel': (-15",
#    '12)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (628",
#    '40)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:11,665',
#   '4',
#   ["'rel': (-7",
#    '6)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (621",
#    '46)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:11,681',
#   '4',
#   ["'rel': (-2",
#    '3)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (619",
#    '49)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:11,699',
#   '4',
#   ["'rel': (-2",
#    '3)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (617",
#    '52)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:11,715',
#   '4',
#   ["'rel': (0",
#    '1)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (617",
#    '53)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:11,806',
#   '4',
#   ["'rel': (8",
#    '2)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (625",
#    '55)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:11,817',
#   '4',
#   ["'rel': (3",
#    '1)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (628",
#    '56)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:11,837',
#   '4',
#   ["'rel': (4",
#    '1)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (632",
#    '57)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:11,856',
#   '5',
#   ["'button': 1", "'pos': (635", '58)', "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:11,856',
#   '9.1',
#   ["'pos': (637,59),'distance: 58.82176467941097,'relative_loc: (34",
#    "48),'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:11,857',
#   '4',
#   ["'rel': (2",
#    '1)',
#    "'buttons': (1",
#    '0',
#    '0)',
#    "'pos': (637",
#    '59)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:11,970',
#   '4',
#   ["'rel': (3",
#    '0)',
#    "'buttons': (1",
#    '0',
#    '0)',
#    "'pos': (640",
#    '59)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:11,993',
#   '6',
#   ["'button': 1", "'pos': (640", '59)', "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:12,272',
#   '4',
#   ["'rel': (0",
#    '3)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (640",
#    '62)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:12,382',
#   '4',
#   ["'rel': (-15",
#    '66)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (625",
#    '128)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:12,631',
#   '4',
#   ["'rel': (-143",
#    '127)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (482",
#    '255)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:12,647',
#   '4',
#   ["'rel': (-8",
#    '3)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (474",
#    '258)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:12,663',
#   '4',
#   ["'rel': (-1",
#    '0)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (473",
#    '258)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:12,766',
#   '4',
#   ["'rel': (-1",
#    '0)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (472",
#    '258)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:12,784',
#   '4',
#   ["'rel': (-15",
#    '6)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (457",
#    '264)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:12,907',
#   '4',
#   ["'rel': (-43",
#    '16)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (414",
#    '280)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:13,041',
#   '4',
#   ["'rel': (-25",
#    '40)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (389",
#    '320)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:13,170',
#   '4',
#   ["'rel': (22",
#    '66)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (411",
#    '386)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:13,299',
#   '4',
#   ["'rel': (-4",
#    '-2)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (407",
#    '384)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:13,315',
#   '4',
#   ["'rel': (-49",
#    '-44)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (358",
#    '340)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:13,332',
#   '4',
#   ["'rel': (-62",
#    '-58)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (296",
#    '282)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:13,348',
#   '4',
#   ["'rel': (-40",
#    '-39)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (256",
#    '243)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:13,365',
#   '4',
#   ["'rel': (-31",
#    '-29)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (225",
#    '214)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:13,383',
#   '4',
#   ["'rel': (-15",
#    '-3)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (210",
#    '211)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:13,622',
#   '5',
#   ["'button': 1", "'pos': (210", '211)', "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:13,622',
#   '8',
#   ["'reason': <bound method GameManager.pause of <game.GameManager object at 0x000001C8561F5320>> "]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:14,478',
#   '7',
#   ["'': hit_conf49 "]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:14,658',
#   '7',
#   ["'': reward_conf50 "]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:14,880',
#   '7',
#   ["'': player_skill50 "]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:14,880',
#   '9.1',
#   ["'pos': (210,211),'distance: 52.20153254455275,'relative_loc: (31",
#    "42),'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:14,987',
#   '2',
#   ["'scancode': 4",
#    "'key': 51",
#    "'window': None",
#    "'mod': 0",
#    "'unicode': '3'"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:14,987',
#   '4',
#   ["'rel': (-4",
#    '-5)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (722",
#    '523)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:15,042',
#   '3',
#   ["'scancode': 3", "'key': 50", "'window': None", "'mod': 0"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:15,108',
#   '3',
#   ["'scancode': 4", "'key': 51", "'window': None", "'mod': 0"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:15,401',
#   '4',
#   ["'rel': (-78",
#    '2)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (644",
#    '525)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:15,592',
#   '4',
#   ["'rel': (-126",
#    '-89)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (518",
#    '436)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:15,608',
#   '4',
#   ["'rel': (0",
#    '-11)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (518",
#    '425)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:15,623',
#   '4',
#   ["'rel': (0",
#    '-8)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (518",
#    '417)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:15,643',
#   '4',
#   ["'rel': (0",
#    '-4)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (518",
#    '413)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:15,660',
#   '4',
#   ["'rel': (-1",
#    '-6)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (517",
#    '407)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:15,675',
#   '4',
#   ["'rel': (-4",
#    '-7)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (513",
#    '400)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:15,693',
#   '4',
#   ["'rel': (-14",
#    '-18)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (499",
#    '382)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:15,711',
#   '4',
#   ["'rel': (-32",
#    '-29)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (467",
#    '353)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:15,726',
#   '4',
#   ["'rel': (-15",
#    '-12)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (452",
#    '341)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:15,743',
#   '4',
#   ["'rel': (-3",
#    '-3)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (449",
#    '338)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:15,760',
#   '4',
#   ["'rel': (-1",
#    '0)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (448",
#    '338)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:16,049',
#   '4',
#   ["'rel': (-2",
#    '31)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (446",
#    '369)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:16,140',
#   '4',
#   ["'rel': (-8",
#    '2)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (438",
#    '371)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:16,149',
#   '4',
#   ["'rel': (4",
#    '-3)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (442",
#    '368)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:16,162',
#   '4',
#   ["'rel': (63",
#    '-24)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (505",
#    '344)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:16,180',
#   '4',
#   ["'rel': (176",
#    '-72)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (681",
#    '272)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:16,196',
#   '4',
#   ["'rel': (92",
#    '-56)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (773",
#    '216)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:16,214',
#   '4',
#   ["'rel': (41",
#    '-54)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (814",
#    '162)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:16,230',
#   '4',
#   ["'rel': (6",
#    '-29)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (820",
#    '133)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:16,248',
#   '4',
#   ["'rel': (-3",
#    '-20)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (817",
#    '113)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:16,265',
#   '4',
#   ["'rel': (-7",
#    '-13)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (810",
#    '100)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:16,282',
#   '4',
#   ["'rel': (-10",
#    '-8)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (800",
#    '92)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:16,298',
#   '4',
#   ["'rel': (-7",
#    '-5)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (793",
#    '87)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:16,315',
#   '4',
#   ["'rel': (-10",
#    '-5)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (783",
#    '82)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:16,332',
#   '4',
#   ["'rel': (-6",
#    '-2)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (777",
#    '80)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:16,349',
#   '4',
#   ["'rel': (-1",
#    '-1)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (776",
#    '79)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:16,366',
#   '4',
#   ["'rel': (-1",
#    '0)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (775",
#    '79)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:16,383',
#   '4',
#   ["'rel': (-4",
#    '-2)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (771",
#    '77)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:16,401',
#   '4',
#   ["'rel': (-7",
#    '-1)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (764",
#    '76)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:16,418',
#   '4',
#   ["'rel': (-10",
#    '-1)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (754",
#    '75)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:16,435',
#   '4',
#   ["'rel': (-10",
#    '0)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (744",
#    '75)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:16,452',
#   '4',
#   ["'rel': (-21",
#    '-1)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (723",
#    '74)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:16,470',
#   '4',
#   ["'rel': (-22",
#    '-1)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (701",
#    '73)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:16,486',
#   '4',
#   ["'rel': (-16",
#    '-1)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (685",
#    '72)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:16,505',
#   '4',
#   ["'rel': (-10",
#    '-2)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (675",
#    '70)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:16,521',
#   '4',
#   ["'rel': (-6",
#    '-1)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (669",
#    '69)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:16,540',
#   '4',
#   ["'rel': (-13",
#    '-4)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (656",
#    '65)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:16,554',
#   '4',
#   ["'rel': (-5",
#    '-1)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (651",
#    '64)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:16,606',
#   '4',
#   ["'rel': (-1",
#    '0)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (650",
#    '64)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:16,627',
#   '4',
#   ["'rel': (-5",
#    '-1)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (645",
#    '63)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:16,639',
#   '4',
#   ["'rel': (-4",
#    '-1)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (641",
#    '62)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:16,656',
#   '4',
#   ["'rel': (-1",
#    '0)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (640",
#    '62)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:16,689',
#   '5',
#   ["'button': 1", "'pos': (640", '62)', "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:16,689',
#   '9.1',
#   ["'pos': (640,62),'distance: 63.00793600809346,'relative_loc: (37",
#    "51),'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:16,689',
#   '8',
#   ["'reason': <bound method GameManager.pause of <game.GameManager object at 0x000001C8561F5320>> "]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:18,480',
#   '3',
#   ["'scancode': 46", "'key': 99", "'window': None", "'mod': 0"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:18,879',
#   '4',
#   ["'rel': (-93",
#    '63)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (581",
#    '254)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:19,087',
#   '4',
#   ["'rel': (0",
#    '7)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (581",
#    '261)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:19,102',
#   '4',
#   ["'rel': (-6",
#    '-4)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (575",
#    '257)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:19,119',
#   '4',
#   ["'rel': (-23",
#    '-19)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (552",
#    '238)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:19,137',
#   '4',
#   ["'rel': (-19",
#    '-16)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (533",
#    '222)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:19,154',
#   '4',
#   ["'rel': (-22",
#    '-16)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (511",
#    '206)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:19,171',
#   '4',
#   ["'rel': (-13",
#    '-7)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (498",
#    '199)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:19,187',
#   '4',
#   ["'rel': (-1",
#    '-2)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (497",
#    '197)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:19,352',
#   '4',
#   ["'rel': (3",
#    '-17)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (500",
#    '180)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:19,457',
#   '4',
#   ["'rel': (3",
#    '-6)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (503",
#    '174)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:19,566',
#   '4',
#   ["'rel': (2",
#    '1)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (505",
#    '175)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:19,572',
#   '4',
#   ["'rel': (0",
#    '2)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (505",
#    '177)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:19,588',
#   '4',
#   ["'rel': (-14",
#    '9)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (491",
#    '186)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
# ...
#    '396)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:56,901',
#   '4',
#   ["'rel': (-1",
#    '-1)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (181",
#    '395)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:57,139',
#   '5',
#   ["'button': 1", "'pos': (181", '395)', "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:57,139',
#   '8',
#   ["'reason': <bound method GameManager.pause of <game.GameManager object at 0x000001C8561F5320>> "]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:58,562',
#   '9.1',
#   ["'pos': (194,385),'distance: 77.3692445355388,'relative_loc: (75",
#    "19),'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:58,700',
#   '3',
#   ["'scancode': 46", "'key': 99", "'window': None", "'mod': 0"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:59,300',
#   '4',
#   ["'rel': (52",
#    '0)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (246",
#    '385)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:59,317',
#   '4',
#   ["'rel': (9",
#    '1)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (255",
#    '386)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:59,332',
#   '4',
#   ["'rel': (16",
#    '0)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (271",
#    '386)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:59,351',
#   '4',
#   ["'rel': (14",
#    '1)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (285",
#    '387)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:59,368',
#   '4',
#   ["'rel': (34",
#    '0)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (319",
#    '387)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:59,384',
#   '4',
#   ["'rel': (34",
#    '-1)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (353",
#    '386)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:59,401',
#   '4',
#   ["'rel': (27",
#    '-1)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (380",
#    '385)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:59,418',
#   '4',
#   ["'rel': (22",
#    '0)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (402",
#    '385)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:59,434',
#   '4',
#   ["'rel': (12",
#    '-1)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (414",
#    '384)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:59,452',
#   '4',
#   ["'rel': (10",
#    '0)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (424",
#    '384)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:59,467',
#   '4',
#   ["'rel': (6",
#    '-1)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (430",
#    '383)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:59,586',
#   '4',
#   ["'rel': (45",
#    '-19)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (475",
#    '364)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:59,712',
#   '4',
#   ["'rel': (41",
#    '-29)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (516",
#    '335)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:59,832',
#   '4',
#   ["'rel': (-36",
#    '-4)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (480",
#    '331)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:59,837',
#   '4',
#   ["'rel': (-9",
#    '0)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (471",
#    '331)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:59,852',
#   '4',
#   ["'rel': (-15",
#    '0)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (456",
#    '331)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:59,869',
#   '4',
#   ["'rel': (-16",
#    '3)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (440",
#    '334)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:59,886',
#   '4',
#   ["'rel': (-29",
#    '9)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (411",
#    '343)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:59,903',
#   '4',
#   ["'rel': (-24",
#    '8)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (387",
#    '351)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:59,920',
#   '4',
#   ["'rel': (-12",
#    '6)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (375",
#    '357)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:59,936',
#   '4',
#   ["'rel': (-2",
#    '0)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (373",
#    '357)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:56:00,055',
#   '5',
#   ["'button': 1", "'pos': (373", '357)', "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:56:00,056',
#   '8',
#   ["'reason': <bound method GameManager.pause of <game.GameManager object at 0x000001C8561F5320>> "]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:56:00,619',
#   '7',
#   ["'': hit_conf49 "]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:56:00,906',
#   '7',
#   ["'': reward_conf49 "]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:56:01,110',
#   '7',
#   ["'': player_skill50 "]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:56:01,110',
#   '9.4',
#   ["'pos': (373,357),'distance: 62.51399843235114,'relative_loc: (-8",
#    "62),'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:56:01,239',
#   '3',
#   ["'scancode': 3", "'key': 50", "'window': None", "'mod': 0"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:56:01,686',
#   '4',
#   ["'rel': (2",
#    '4)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (411",
#    '354)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:56:01,697',
#   '4',
#   ["'rel': (4",
#    '7)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (415",
#    '361)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:56:01,717',
#   '4',
#   ["'rel': (3",
#    '14)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (418",
#    '375)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:56:01,734',
#   '4',
#   ["'rel': (2",
#    '7)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (420",
#    '382)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:56:01,750',
#   '4',
#   ["'rel': (0",
#    '4)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (420",
#    '386)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:56:01,770',
#   '4',
#   ["'rel': (1",
#    '3)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (421",
#    '389)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:56:01,787',
#   '4',
#   ["'rel': (0",
#    '3)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (421",
#    '392)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:56:01,818',
#   '4',
#   ["'rel': (0",
#    '1)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (421",
#    '393)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:56:01,854',
#   '4',
#   ["'rel': (0",
#    '1)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (421",
#    '394)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:56:01,961',
#   '4',
#   ["'rel': (-30",
#    '25)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (391",
#    '419)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:56:02,066',
#   '4',
#   ["'rel': (-3",
#    '-1)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (388",
#    '418)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:56:02,072',
#   '4',
#   ["'rel': (-1",
#    '0)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (387",
#    '418)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:56:02,175',
#   '4',
#   ["'rel': (2",
#    '-2)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (389",
#    '416)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:56:02,181',
#   '4',
#   ["'rel': (3",
#    '-2)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (392",
#    '414)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:56:02,197',
#   '4',
#   ["'rel': (10",
#    '-8)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (402",
#    '406)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:56:02,211',
#   '4',
#   ["'rel': (5",
#    '-5)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (407",
#    '401)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:56:02,229',
#   '4',
#   ["'rel': (5",
#    '-4)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (412",
#    '397)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:56:02,245',
#   '4',
#   ["'rel': (3",
#    '-3)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (415",
#    '394)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:56:02,263',
#   '4',
#   ["'rel': (5",
#    '-3)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (420",
#    '391)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:56:02,279',
#   '4',
#   ["'rel': (33",
#    '-8)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (453",
#    '383)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:56:02,297',
#   '4',
#   ["'rel': (66",
#    '-9)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (519",
#    '374)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:56:02,313',
#   '4',
#   ["'rel': (50",
#    '2)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (569",
#    '376)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:56:02,330',
#   '4',
#   ["'rel': (50",
#    '6)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (619",
#    '382)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:56:02,347',
#   '4',
#   ["'rel': (38",
#    '3)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (657",
#    '385)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:56:02,366',
#   '4',
#   ["'rel': (20",
#    '3)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (677",
#    '388)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:56:02,381',
#   '4',
#   ["'rel': (1",
#    '0)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (678",
#    '388)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:56:02,878',
#   '4',
#   ["'rel': (4",
#    '-18)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (682",
#    '370)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:56:02,893',
#   '4',
#   ["'rel': (36",
#    '-79)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (718",
#    '291)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:56:02,911',
#   '4',
#   ["'rel': (124",
#    '-67)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (842",
#    '224)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:56:02,927',
#   '4',
#   ["'rel': (37",
#    '-62)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (879",
#    '162)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:56:02,944',
#   '4',
#   ["'rel': (1",
#    '0)',
#    "'buttons': (0",
#    '0',
#    '0)',
#    "'pos': (880",
#    '162)',
#    "'window': None"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:56:03,492',
#   '2',
#   ["'scancode': 25",
#    "'key': 112",
#    "'window': None",
#    "'mod': 0",
#    "'unicode': 'p'"]),
#  (<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:56:03,492',
#   '8',
#   ["'reason': <bound method GameManager.pause of <game.GameManager object at 0x000001C8561F5320>> "])]

# %% [markdown]
# for the hit events, take the next  ratings and append them (you append in history, as that is the most current, not exactly sure hwo I should do that right now
#
# try next line and if it's rating then refresh, else assume old ratings are current (but include a timestamp on them)')

# %%
table = [['file', 'date', 'time', 'event', 'pos_x', 'pos_y', 'relative_loc_x', 'relative_loc_y']]
headers = table.pop(0)
for line in file_data_table:
    file = line[0]
    date = line[1]
    time = line[2]
    event = line[3]
    if event in ['9.1','9.2','9.3', '9.4']:
        details = line[4][0].split(',\'')
        pos = details[0].split('(')[1].split(')')[0]
        pos_x = pos.split(',')[0]
        pos_y = pos.split(',')[1]
        distance = details[1].split(' ')[1]
        relative_loc = details[2].split('(')[1].split(')')[0]
        relative_loc_x = relative_loc.split(',')[0]
        relative_loc_y = relative_loc.split(', ')[1]
        entry = [file, date, time, event, pos_x, pos_y, relative_loc_x, relative_loc_y]
        table.append(entry)

# %%
cleaned_list
# Out:
# [['file',
#   'date',
#   'time',
#   'event',
#   'pos_x',
#   'pos_y',
#   'relative_loc_x',
#   'relative_loc_y'],
#  [<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:05,895',
#   '9.1',
#   '139',
#   '104',
#   '44',
#   '61'],
#  [<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:10,056',
#   '9.1',
#   '697',
#   '280',
#   '39',
#   '48'],
#  [<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:11,856',
#   '9.1',
#   '637',
#   '59',
#   '34',
#   '48'],
#  [<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:14,880',
#   '9.1',
#   '210',
#   '211',
#   '31',
#   '42'],
#  [<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:16,689',
#   '9.1',
#   '640',
#   '62',
#   '37',
#   '51'],
#  [<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:21,365',
#   '9.1',
#   '171',
#   '428',
#   '52',
#   '62'],
#  [<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:23,463',
#   '9.1',
#   '153',
#   '93',
#   '58',
#   '50'],
#  [<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:26,006',
#   '9.1',
#   '217',
#   '241',
#   '38',
#   '72'],
#  [<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:27,717',
#   '9.1',
#   '508',
#   '140',
#   '44',
#   '21'],
#  [<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:30,796',
#   '9.1',
#   '199',
#   '430',
#   '80',
#   '64'],
#  [<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:35,302',
#   '9.4',
#   '606',
#   '364',
#   '142',
#   '245'],
#  [<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:37,837',
#   '9.1',
#   '454',
#   '527',
#   '50',
#   '48'],
#  [<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:39,280',
#   '9.4',
#   '572',
#   '418',
#   '-31',
#   '407'],
#  [<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:42,207',
#   '9.4',
#   '572',
#   '418',
#   '-31',
#   '407'],
#  [<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:43,771',
#   '9.1',
#   '695',
#   '290',
#   '37',
#   '58'],
#  [<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:46,694',
#   '9.1',
#   '244',
#   '226',
#   '65',
#   '57'],
#  [<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:48,274',
#   '9.1',
#   '671',
#   '281',
#   '13',
#   '49'],
#  [<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:51,194',
#   '9.1',
#   '665',
#   '403',
#   '29',
#   '37'],
#  [<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:52,943',
#   '9.1',
#   '662',
#   '71',
#   '59',
#   '60'],
#  [<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:55,371',
#   '9.4',
#   '178',
#   '221',
#   '-1',
#   '52'],
#  [<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:55:58,562',
#   '9.1',
#   '194',
#   '385',
#   '75',
#   '19'],
#  [<_io.TextIOWrapper name='logs\\BDM-WAM 1574528099.0686333.log' mode='r' encoding='cp1252'>,
#   '2019-11-23',
#   '16:56:01,110',
#   '9.4',
#   '373',
#   '357',
#   '-8',
#   '62']]

# %%
df = pd.DataFrame(cleaned_list[1:], columns = headers)

# %%
df
# Out:
#                                                  file        date  \
# 0   <_io.TextIOWrapper name='logs\\BDM-WAM 1574528...  2019-11-23
# 1   <_io.TextIOWrapper name='logs\\BDM-WAM 1574528...  2019-11-23
# 2   <_io.TextIOWrapper name='logs\\BDM-WAM 1574528...  2019-11-23
# 3   <_io.TextIOWrapper name='logs\\BDM-WAM 1574528...  2019-11-23
# 4   <_io.TextIOWrapper name='logs\\BDM-WAM 1574528...  2019-11-23
# 5   <_io.TextIOWrapper name='logs\\BDM-WAM 1574528...  2019-11-23
# 6   <_io.TextIOWrapper name='logs\\BDM-WAM 1574528...  2019-11-23
# 7   <_io.TextIOWrapper name='logs\\BDM-WAM 1574528...  2019-11-23
# 8   <_io.TextIOWrapper name='logs\\BDM-WAM 1574528...  2019-11-23
# 9   <_io.TextIOWrapper name='logs\\BDM-WAM 1574528...  2019-11-23
# 10  <_io.TextIOWrapper name='logs\\BDM-WAM 1574528...  2019-11-23
# 11  <_io.TextIOWrapper name='logs\\BDM-WAM 1574528...  2019-11-23
# 12  <_io.TextIOWrapper name='logs\\BDM-WAM 1574528...  2019-11-23
# 13  <_io.TextIOWrapper name='logs\\BDM-WAM 1574528...  2019-11-23
# 14  <_io.TextIOWrapper name='logs\\BDM-WAM 1574528...  2019-11-23
# 15  <_io.TextIOWrapper name='logs\\BDM-WAM 1574528...  2019-11-23
# 16  <_io.TextIOWrapper name='logs\\BDM-WAM 1574528...  2019-11-23
# 17  <_io.TextIOWrapper name='logs\\BDM-WAM 1574528...  2019-11-23
# 18  <_io.TextIOWrapper name='logs\\BDM-WAM 1574528...  2019-11-23
# 19  <_io.TextIOWrapper name='logs\\BDM-WAM 1574528...  2019-11-23
# 20  <_io.TextIOWrapper name='logs\\BDM-WAM 1574528...  2019-11-23
# 21  <_io.TextIOWrapper name='logs\\BDM-WAM 1574528...  2019-11-23
#
#             time event pos_x pos_y relative_loc_x relative_loc_y
# 0   16:55:05,895   9.1   139   104             44             61
# 1   16:55:10,056   9.1   697   280             39             48
# 2   16:55:11,856   9.1   637    59             34             48
# 3   16:55:14,880   9.1   210   211             31             42
# 4   16:55:16,689   9.1   640    62             37             51
# 5   16:55:21,365   9.1   171   428             52             62
# 6   16:55:23,463   9.1   153    93             58             50
# 7   16:55:26,006   9.1   217   241             38             72
# 8   16:55:27,717   9.1   508   140             44             21
# 9   16:55:30,796   9.1   199   430             80             64
# 10  16:55:35,302   9.4   606   364            142            245
# 11  16:55:37,837   9.1   454   527             50             48
# 12  16:55:39,280   9.4   572   418            -31            407
# 13  16:55:42,207   9.4   572   418            -31            407
# 14  16:55:43,771   9.1   695   290             37             58
# 15  16:55:46,694   9.1   244   226             65             57
# 16  16:55:48,274   9.1   671   281             13             49
# 17  16:55:51,194   9.1   665   403             29             37
# 18  16:55:52,943   9.1   662    71             59             60
# 19  16:55:55,371   9.4   178   221             -1             52
# 20  16:55:58,562   9.1   194   385             75             19
# 21  16:56:01,110   9.4   373   357             -8             62
